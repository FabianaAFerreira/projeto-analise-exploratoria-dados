# %%
# Criando uma nova célula para analisar o tipo de contrato
plt.figure(figsize=(10, 5))

#Gráfico cruzando o tipo de contrato com quem cancelou
sns.countplot(
    x="Contract", hue="Churn", data=df_churn, palette="Set2"
)

#Configurando títulos profissionais
plt.title(
    "Impacto do tipo de Contrato no Cancelamento de Clientes",
    fontsize=14,
    pad=15,
)
plt.xlabel("Tipo de Contrato (Contract)", fontsize=12)
plt.ylabel("Quantidade de Cliente", fontsize=12)
plt.legend(title="Cancelou? (Churn)")

# Exibindo o novo gráfico
plt.show()

# %%
# Verificando os tipos de dados de cada coluna
print("---INFORMAÇÕES GERAIS DO DATASET ---")
df_churn.info()
# Out:
# ---INFORMAÇÕES GERAIS DO DATASET ---
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   str
#  1   gender            7043 non-null   str
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   str
#  4   Dependents        7043 non-null   str
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   str
#  7   MultipleLines     7043 non-null   str
#  8   InternetService   7043 non-null   str
#  9   OnlineSecurity    7043 non-null   str
#  10  OnlineBackup      7043 non-null   str
#  11  DeviceProtection  7043 non-null   str
#  12  TechSupport       7043 non-null   str
#  13  StreamingTV       7043 non-null   str
#  14  StreamingMovies   7043 non-null   str
#  15  Contract          7043 non-null   str
# ...

# %%
# 1. Convertendo espaços em branco para valores nulos (NaN) e forçando o tipo numérico
df_churn["TotalCharges"] = pd.to_numeric(
    df_churn["TotalCharges"], errors="coerce"
)

# 2. Verificando quantas linhas ficaram nulas após a conversão
valores_nulos = df_churn["TotalCharges"].isnull().sum()
print(f"Quantidade de valores nulos em TotalCharges: {valores_nulos}")

# 3. Como são poucas linhas (apenas 11), vamos eliminá-las para não atrapalhar a análise
df_churn = df_churn.dropna(subset=["TotalCharges"])
print("Valores nulos eliminados com sucesso!")
# Out:
# Quantidade de valores nulos em TotalCharges: 11
# Valores nulos eliminados com sucesso!

# %%
# Criando uma nova célula abaixo para o gráfico
import matplotlib.pyplot as plt
import seaborn as sns

# Configurando o estilo do gráfico
sns.set_theme(style="whitegrid")
plt.figure(figsize=(6, 5))

# Criando o gráfico de contagem de Churn
ax = sns.countplot(x="Churn", data=df_churn, palette="Set2")

# Adicionando título de forma profissional
plt.title("Distrbuição de cliente por Churn (Cancelamento)", fontsize=14, pad=15)
plt.xlabel("Cancelou o Serviço? (Churn)", fontsize=12)
plt.ylabel("Quantidade de Cliente", fontsize=12)

# Mpstrando o gráfico na tela
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_4456\2015871769.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x="Churn", data=df_churn, palette="Set2")

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Configurando o tamanho do gráfico
plt.figure(figsize=(7, 5))

# Criando um gráfico de caixas (Boxplot) para comparar a distribuição de gastos
sns.boxplot(x="Churn", y="TotalCharges", data=df_churn, palette="Set2")

# Títulos profissionais
plt.title(
    "Distribuição do Gasto Total Acumulado por Status de Churn",
    fontsize=14,
    pad=15,
)
plt.xlabel("Cancelou o Serviço? (Churn)", fontsize=12)
plt.ylabel("Faturamento Total Acumulado ($)", fontsize=12)

# Exibindo o gráfico
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_4456\3221194946.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Churn", y="TotalCharges", data=df_churn, palette="Set2")

# %%
plt.figure(figsize=(10, 5))

# Criando um gráfico de distribuição (KDE) para ver a curva de meses
sns.kdeplot(
    data=df_churn,
    x="tenure",
    hue="Churn",
    shade=True,
    palette="Set2",
)

# Títulos
plt.title(
    "Densidade do Tempo de Permanência (Meses) por Churn",
    fontsize=14,
    pad=15,
)
plt.xlabel("Meses de Contrato (tenure)", fontsize=12)
plt.ylabel("Densidade", fontsize=12)

plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_4456\2769938226.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# Carregando a base de dados de Churn
df_churn = pd.read_csv("WA_Fn-UseC_-Telco-Customer-Churn.csv")

# Exibindo as primeiras linhas do arquivo
df_churn.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...
